# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df0=pd.read_csv(r"C:\Users\Abhishek Gour\Downloads\creditcard.csv (2)\creditcard.csv (1).zip")

# %%
df0
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df0.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.918649e-15  5.682686e-16 -8.761736e-15  2.811118e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552103e-15  2.040130e-15 -1.698953e-15 -1.893285e-16 -3.147640e-15
# ...

# %%
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
#NUMBERS OF CRADS
len(df0['Class']==0)
# Out:
# 284807

# %%
#NUMBERS OF FRAUDS IN CREDIT CARDS 
len(df0[df0['Class']==1])
# Out:
# 492

# %%
df0.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df0.shape
# Out:
# (284807, 31)

# %%
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
# Feature scaling
df0.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df0.describe().round(2).style.background_gradient()
# Out:
# <style type="text/css">
# #T_aab69_row0_col0, #T_aab69_row0_col1, #T_aab69_row0_col2, #T_aab69_row0_col3, #T_aab69_row0_col4, #T_aab69_row0_col5, #T_aab69_row0_col6, #T_aab69_row0_col7, #T_aab69_row0_col8, #T_aab69_row0_col9, #T_aab69_row0_col10, #T_aab69_row0_col11, #T_aab69_row0_col12, #T_aab69_row0_col13, #T_aab69_row0_col14, #T_aab69_row0_col15, #T_aab69_row0_col16, #T_aab69_row0_col17, #T_aab69_row0_col18, #T_aab69_row0_col19, #T_aab69_row0_col20, #T_aab69_row0_col21, #T_aab69_row0_col22, #T_aab69_row0_col23, #T_aab69_row0_col24, #T_aab69_row0_col25, #T_aab69_row0_col26, #T_aab69_row0_col27, #T_aab69_row0_col28, #T_aab69_row0_col29, #T_aab69_row0_col30 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_aab69_row1_col0 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# ...

# %%
df0.duplicated().sum()
# Out:
# 1081

# %%
#we must remove duplicates
df0.drop_duplicates(inplace=True)

# %%
## PArt5 check imblance dataset
## It is imbalance dataset
### however its domain specific problem abd we cant not say that every two transisition is fraud
df0['Class'].value_counts()
# Out:
# 0    283253
# 1       473
# Name: Class, dtype: int64

# %%
# Exploratory Data analysis

# %%
plt.figure(figsize=(10,6))
labels=['Not Fraud' , 'Frauds']
explode = [.01,.01]
color=['skyblue' , 'Red']
sizes=df0.Class.value_counts().values

plt.pie(sizes,explode,labels,autopct="%1.1f%%", colors = color)
plt.show()

# %%
count_classes=pd.value_counts(df0['Class'],sort=True)
count_classes.plot(kind='bar',rot=0)
plt.title('Transisiiton classess distribution')
plt.xticks(range(2))
plt.show()

# %%
fraud=df0[df0['Class']==1]
normal=df0[df0['Class']==0]
print(fraud.shape , normal.shape)
# Out:
# (473, 31) (283253, 31)

# %%
fraud.Amount.describe()
# Out:
# count     473.000000
# mean      123.871860
# std       260.211041
# min         0.000000
# 25%         1.000000
# 50%         9.820000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
normal.Amount.describe()
# Out:
# count    283253.000000
# mean         88.413575
# std         250.379023
# min           0.000000
# 25%           5.670000
# 50%          22.000000
# 75%          77.460000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
f,(ax1,ax2)=plt.subplots(2,1,sharex=True)
f.suptitle('Amount per transisition by class')
bins =50
ax1.hist(fraud.Amount , bins=bins)
ax1.set_title('Fraud')

ax2.hist(normal.Amount,bins=bins)
ax2.set_title('normal')

plt.xlabel('amount in $')
plt.ylabel('Number of transisition')

plt.xlim(0,25000)
plt.yscale('log')
plt.show()

# %%
f , (ax1,ax2)=plt.subplots(2,1,sharex=True)
f.suptitle('Time vs Amount by class')

ax1.scatter(fraud.Time ,fraud.Amount,color = 'green')
ax1.set_title('Fraud')

ax2.scatter(normal.Time,normal.Amount,color = 'deeppink')
ax1.set_title('normal')
# Out:
# Text(0.5, 1.0, 'normal')

# %%
sns.distplot(df0['Time'])
plt.show()
# Out:
# C:\Users\Abhishek Gour\anaconda2\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(25,10))
sns.heatmap(df0.corr(),annot=True,cmap='rainbow')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # split data into traing and test dataset

# %%
x=df0.iloc[:,0:-1]
y=df0.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train , x_test ,y_train ,y_test =train_test_split(x,y,train_size=0.75,random_state=101)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (212794, 30)
# (70932, 30)
# (212794,)
# (70932,)

# %% [markdown]
# # Logistic Regression¶
# # classification model
# # Binary classification
# # Normal transaction or Fraud transcation

# %%
from sklearn.linear_model import LogisticRegression
logit=LogisticRegression()
logit.fit(x_train,y_train)
# Out:
# C:\Users\Abhishek Gour\anaconda2\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
## preict model with test datatest

y_pred_train =logit.predict(x_train)
y_pred_test=logit.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
print(confusion_matrix(y_train,y_pred_train))
print('********')
print(confusion_matrix(y_test,y_pred_test))
# Out:
# [[212335    102]
#  [   119    238]]
# ********
# [[70782    34]
#  [   33    83]]

# %%
print(classification_report(y_train,y_pred_train))
print('********')
print(classification_report(y_test,y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    212437
#            1       0.70      0.67      0.68       357
#
#     accuracy                           1.00    212794
#    macro avg       0.85      0.83      0.84    212794
# weighted avg       1.00      1.00      1.00    212794
#
# ********
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     70816
#            1       0.71      0.72      0.71       116
#
#     accuracy                           1.00     70932
#    macro avg       0.85      0.86      0.86     70932
# weighted avg       1.00      1.00      1.00     70932

# %%
print(accuracy_score(y_train,y_pred_train))
print('********')
print(accuracy_score(y_test,y_pred_test))
# Out:
# 0.9989614368826188
# ********
# 0.9990554333728078

# %%
x=df0.iloc[:,1:30].values
y=df0.iloc[:,30].values

# %%
print("Input Range : ", x.shape)
print("Input Range :", y.shape)
# Out:
# Input Range :  (283726, 29)
# Input Range : (283726,)

# %%
print("Class Labels  \n", y)
# Out:
# Class Labels
#  [0 0 0 ... 0 0 0]

# %%
df0.isnull().values.any()
# Out:
# False

# %%
fraud_data = df0[df0['Class']==1]

normal_data = df0[df0['Class']==0]

# %%
print(fraud_data.shape,normal_data.shape)
# Out:
# (473, 31) (283253, 31)

# %%
fraud_data.Amount.describe()
# Out:
# count     473.000000
# mean      123.871860
# std       260.211041
# min         0.000000
# 25%         1.000000
# 50%         9.820000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
normal_data.Amount.describe()
# Out:
# count    283253.000000
# mean         88.413575
# std         250.379023
# min           0.000000
# 25%           5.670000
# 50%          22.000000
# 75%          77.460000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
# checking distribution of numerical values in the dataset
df0['Class'].value_counts()
# Out:
# 0    283253
# 1       473
# Name: Class, dtype: int64

# %%
# checking the class distribution of the target variable in percentage
print((df0.groupby('Class')['Class'].count()/df0['Class'].count()) *100)
((df0.groupby('Class')['Class'].count()/df0['Class'].count())*100).plot.pie()
# Out:
# Class
# 0    99.83329
# 1     0.16671
# Name: Class, dtype: float64
# <AxesSubplot:ylabel='Class'>

# %%
# checking the % distribution of normal vs fraud
classes=df0['Class'].value_counts()
normal=classes[0]/df0['Class'].count()*100
fraud=classes[1]/df0['Class'].count()*100


print(normal)
print(fraud)
# Out:
# 99.83328986416473
# 0.1667101358352777

# %%
# checking the correlation
corr=df0.corr()
corr
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# Time    1.000000  0.117927 -0.010556 -0.422054 -0.105845  0.173223 -0.063279
# V1      0.117927  1.000000  0.006875 -0.008112  0.002257 -0.007036  0.000413
# V2     -0.010556  0.006875  1.000000  0.005278 -0.001495  0.005210 -0.000594
# V3     -0.422054 -0.008112  0.005278  1.000000  0.002829 -0.006879 -0.001511
# V4     -0.105845  0.002257 -0.001495  0.002829  1.000000  0.001744 -0.000880
# V5      0.173223 -0.007036  0.005210 -0.006879  0.001744  1.000000 -0.000938
# V6     -0.063279  0.000413 -0.000594 -0.001511 -0.000880 -0.000938  1.000000
# V7      0.085335 -0.009173  0.007425 -0.011721  0.004657 -0.008709  0.000436
# V8     -0.038203 -0.001168  0.002899 -0.001815  0.000890  0.001430  0.003036
# V9     -0.007861  0.001828 -0.000274 -0.003579  0.002154 -0.001213 -0.000734
# V10     0.031068  0.000815  0.000620 -0.009632  0.002753 -0.006050 -0.002180
# ...

# %%
# checking the correlation in heatmap
plt.figure(figsize=(24,18))

sns.heatmap(corr, cmap="coolwarm", annot=True)
plt.show()

# %%
# splitting the dataset into x and y
y=df0['Class']
x=df0.drop(['Class'], axis=1)

# %%
#checking some rows of x
x.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V20       V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...  0.251412 -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ... -0.069083 -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...  0.524980  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ... -0.208038 -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...  0.408542 -0.009431  0.798278 -0.137458  0.141267
#
# ...

# %%
# checking some rows of y
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Class, dtype: int64

# %%
#2. DATA CLEANING AND EXPLORATION

# %%
df0.columns[df0.isna().any()]
# Out:
# Index([], dtype='object')

# %%
# HOW MANY FRAUD COMPARED TO NON FRAUD

# %%
display(df0.groupby("Class").count())


class_bar=sns.countplot(x=df0["Class"])
ax = plt.gca()
for p in ax.patches:
        ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.3, p.get_height()+500))
class_bar
# Out:
#          Time      V1      V2      V3      V4      V5      V6      V7      V8  \
# Class
# 0      283253  283253  283253  283253  283253  283253  283253  283253  283253
# 1         473     473     473     473     473     473     473     473     473
#
#            V9  ...     V20     V21     V22     V23     V24     V25     V26  \
# Class          ...
# 0      283253  ...  283253  283253  283253  283253  283253  283253  283253
# 1         473  ...     473     473     473     473     473     473     473
#
#           V27     V28  Amount
# Class
# 0      283253  283253  283253
# 1         473     473     473
#
# [2 rows x 30 columns]
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %%
normal.Amount.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\ABHISH~1\AppData\Local\Temp/ipykernel_21000/456811768.py in <module>
# ----> 1 normal.Amount.describe()
#
# AttributeError: 'numpy.float64' object has no attribute 'Amount'

# %%
df0.groupby('Class').mean()

# %%
from pycaret.datasets import get_data
anomaly=get_data('anomaly')
from pycaret.anomaly import*
exp_ano = setup(anomaly)
# Out:
#        Col1      Col2      Col3      Col4      Col5      Col6      Col7  \
# 0  0.263995  0.764929  0.138424  0.935242  0.605867  0.518790  0.912225
# 1  0.546092  0.653975  0.065575  0.227772  0.845269  0.837066  0.272379
# 2  0.336714  0.538842  0.192801  0.553563  0.074515  0.332993  0.365792
# 3  0.092108  0.995017  0.014465  0.176371  0.241530  0.514724  0.562208
# 4  0.325261  0.805968  0.957033  0.331665  0.307923  0.355315  0.501899
#
#        Col8      Col9     Col10
# 0  0.608234  0.723782  0.733591
# 1  0.331679  0.429297  0.367422
# 2  0.861309  0.899017  0.088600
# 3  0.158963  0.073715  0.208463
# 4  0.558449  0.885169  0.182754
# IntProgress(value=0, description='Processing: ', max=3)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                     14:29:22
# Status     . . . . . . . . . . . . . . . . . .  Preparing Data for Modeling
# ---------------------------------------------------------------------------
# ...

# %%
# !pip install pycaret

# %%
anomaly
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ABHISH~1\AppData\Local\Temp/ipykernel_21000/3420185813.py in <module>
# ----> 1 anomaly
#
# NameError: name 'anomaly' is not defined

# %%
iforest=create_model('iforest')
plot_model(iforest)
